# %%
## First, we import all the dependencies that are required and relevant for this assignment.

import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\UTKARSH KUMAR SINGH\Downloads\data (3).csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M          NaN         20.38           77.58        NaN
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.shape
# Out:
# (569, 32)

# %%
df.isnull().sum()
# Out:
# id                          0
# diagnosis                   0
# radius_mean                28
# texture_mean                0
# perimeter_mean              0
# area_mean                  41
# smoothness_mean             0
# compactness_mean            0
# concavity_mean              0
# concave_points_mean         0
# symmetry_mean               0
# fractal_dimension_mean      0
# radius_sd                   0
# texture_sd                  0
# perimeter_sd                0
# area_sd                     0
# smoothness_sd               0
# compactness_sd              0
# concavity_sd                0
# concave_points_sd           0
# symmetry_sd                 0
# fractal_dimension_sd        0
# radius_worst                0
# texture_worst               0
# perimeter_worst             0
# area_worst                  0
# smoothness_worst            0
# compactness_worst           0
# concavity_worst             0
# concave_points_worst        0
# symmetry_worst              0
# ...

# %% [markdown]
# ####  Q1 - There are a few missing values in the data. Identify what fraction of observations have missing values and devise a strategy for the missing value imputation ?

# %% [markdown]
# #### --> Capturing NAN values with a new feature---  It works well if the data are not missing completely at random

# %% [markdown]
# ###### In other words, missing values are totally unrelated to other data. No pattern can be found. In the case of MCAR, the missing data may be the result of human mistake, equipment or system failure, sample loss, or unsatisfactory technicality during the recording of the values. In this task we can use NAN value with new features.

# %%
import numpy as np
df['radius_mean_NAN']=np.where(df['radius_mean'].isnull(),1,0)

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M          NaN         20.38           77.58        NaN
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.radius_mean.median()
# Out:
# 13.4

# %%
df['radius_mean'].fillna(df.radius_mean.median(),inplace=True)

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58        NaN
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
df['area_mean_NAN']=np.where(df['area_mean'].isnull(),1,0)
df.area_mean.median()
df['area_mean'].fillna(df.area_mean.median(),inplace=True)

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %% [markdown]
# ### Advantages
# ####     1- Easy to implement
# ####     2- Captures the importance of missing values

# %% [markdown]
# #### Q2 - What does the distribution of each of those features look like? Explain your answer with the help of graphs and summary statistics.

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
import seaborn as sns

# %%
sns.displot(df["perimeter_mean"], kde = True)

# %%
sns.displot(df["texture_mean"], kde = True)

# %%
sns.displot(df["perimeter_worst"], kde = True)

# %%
sns.displot(df["area_worst"], kde = True)

# %%
sns.displot(df["smoothness_worst"], kde = True)

# %%
sns.displot(df["concavity_mean"], kde = True)

# %%
sns.displot(df["fractal_dimension_worst"], kde = True)

# %%
sns.pairplot(df.iloc[:, 1:5], hue = "diagnosis")

# %% [markdown]
# ##### The relationship between observations of various heights is described by the distribution, a mathematical function. Simply said, a distribution is a grouping of data, or scores, on a variable. These scores are typically listed from smallest to largest, after which they might be displayed graphically. we can clearly said that when in a texture_mean and smooothness_worst are symmetrical or in another words they follw the guassian distribution and rest distributions are skewed in nature.

# %% [markdown]
# #### Q3 -Plot boxplot of all features which have a prefix ‘radius?

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# #### There are only one features which have prefix radius sowe can plot a box plot with help of some functions.

# %%
figure=df.boxplot(column="radius_mean")

# %%
df['radius_mean'].describe()
# Out:
# count    569.000000
# mean      14.137253
# std        3.443406
# min        6.981000
# 25%       11.840000
# 50%       13.400000
# 75%       15.710000
# max       28.110000
# Name: radius_mean, dtype: float64

# %% [markdown]
# ##### It summarises the distribution of each attribute and is univariate in nature. It creates a line for the median value, or middle value. It creates a box around the 25% and the 75%. box plot tells about us:  Min value, Max value, First quartile, Third quartile and median value. we can clearly see that mean and std are different from each other beacause of outliers. So we have some techiniques to handle those outliers with the help of higher and lower fence.

# %% [markdown]
# #### Q4 - Are the scales of the features in the similar range? If not, normalize the data?

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %% [markdown]
# #### Min Max Scaling (### CNN)---Deep Learning Techniques
# #### Min Max Scaling scales the values between 0 to 1. X_scaled = (X - X.min / (X.max - X.min)

# %%
df["diagnosis"].unique()
# Out:
# array(['M', 'B'], dtype=object)

# %%
X = df.drop(columns = "diagnosis", axis = 1)

# %%
Y = df["diagnosis"]

# %%
from sklearn.preprocessing import MinMaxScaler
min_max=MinMaxScaler()
df_minmax=pd.DataFrame(min_max.fit_transform(X),columns=X.columns)
df_minmax.head()
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.000915     0.521037      0.022658        0.545989   0.356389
# 1  0.000915     0.643144      0.272574        0.615783   0.495838
# 2  0.092495     0.601496      0.390260        0.595743   0.443062
# 3  0.092547     0.303800      0.360839        0.233501   0.165408
# 4  0.092559     0.629893      0.156578        0.630986   0.483395
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# 2         0.514309          0.431017        0.462512             0.635686
# 3         0.811321          0.811361        0.565604             0.522863
# 4         0.430351          0.347893        0.463918             0.518390
#
#    symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
import matplotlib.pyplot as plt
plt.hist(df_minmax['texture_mean'],bins=20)
# Out:
# (array([ 7., 10., 43., 53., 72., 82., 80., 65., 54., 35., 26., 14., 15.,
#          6.,  3.,  1.,  2.,  0.,  0.,  1.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_minmax['perimeter_mean'],bins=20)
# Out:
# (array([  4.,  11.,  40.,  53., 100.,  85.,  70.,  46.,  35.,  27.,  22.,
#          27.,  24.,  10.,   4.,   4.,   2.,   1.,   1.,   3.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_minmax['area_mean'],bins=20)
# Out:
# (array([ 31.,  82., 122., 129.,  61.,  30.,  22.,  24.,  24.,  22.,   7.,
#           4.,   3.,   3.,   1.,   1.,   0.,   1.,   0.,   2.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %%
plt.hist(df_minmax["perimeter_mean"],bins=20)
# Out:
# (array([  4.,  11.,  40.,  53., 100.,  85.,  70.,  46.,  35.,  27.,  22.,
#          27.,  24.,  10.,   4.,   4.,   2.,   1.,   1.,   3.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ##### When preparing data for machine learning, normalisation is a scaling technique that modifies the values of numerical columns to use a standard scale. Not all datasets in a model require it. It is only necessary when the ranges of the features in machine learning models differ. We set the all different parameter in one range between 0 to 1.

# %% [markdown]
# #### Q5 - Heat map?

# %%
df_minmax.head(10)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.000915     0.521037      0.022658        0.545989   0.356389
# 1  0.000915     0.643144      0.272574        0.615783   0.495838
# 2  0.092495     0.601496      0.390260        0.595743   0.443062
# 3  0.092547     0.303800      0.360839        0.233501   0.165408
# 4  0.092559     0.629893      0.156578        0.630986   0.483395
# 5  0.000916     0.258839      0.202570        0.267984   0.131597
# 6  0.000917     0.533343      0.347311        0.523875   0.373123
# 7  0.092668     0.318472      0.376057        0.320710   0.174848
# 8  0.000918     0.284869      0.409537        0.302052   0.149918
# 9  0.092715     0.259312      0.484613        0.277659   0.131082
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# ...

# %%
# Correlation

correlation = df_minmax.corr()

# %%
# constructing a heatmap to understand the correlation between the columns
plt.figure(figsize=(10,10))
sns.heatmap(correlation, cbar=True, square=True, fmt = '.1f', annot = True, annot_kws={'size':5}, cmap = 'Accent_r')
# Out:
# <AxesSubplot:>

# %%
df_minmax.head(10)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.000915     0.521037      0.022658        0.545989   0.356389
# 1  0.000915     0.643144      0.272574        0.615783   0.495838
# 2  0.092495     0.601496      0.390260        0.595743   0.443062
# 3  0.092547     0.303800      0.360839        0.233501   0.165408
# 4  0.092559     0.629893      0.156578        0.630986   0.483395
# 5  0.000916     0.258839      0.202570        0.267984   0.131597
# 6  0.000917     0.533343      0.347311        0.523875   0.373123
# 7  0.092668     0.318472      0.376057        0.320710   0.174848
# 8  0.000918     0.284869      0.409537        0.302052   0.149918
# 9  0.092715     0.259312      0.484613        0.277659   0.131082
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# ...

# %%
## k-means clustering

breast_data = df_minmax.iloc[:,[3,4]].values

# %%
print(breast_data)
# Out:
# [[0.54598853 0.35638891]
#  [0.61578329 0.49583798]
#  [0.59574321 0.44306187]
#  ...
#  [0.44578813 0.29507423]
#  [0.66553797 0.46966446]
#  [0.02853984 0.00454819]]

# %%
from sklearn.cluster import KMeans

# %%
# finding wcss value for different number of clusters

wcss = []

for i in range(1,11):
  kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
  kmeans.fit(breast_data)

  wcss.append(kmeans.inertia_)
# Out:
# C:\Users\UTKARSH KUMAR SINGH\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\UTKARSH KUMAR SINGH\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# C:\Users\UTKARSH KUMAR SINGH\anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1332: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=3.
#   warnings.warn(
# ...

# %%
# plot an elbow graph

sns.set()
plt.plot(range(1,11), wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# ##### These coefficients are displayed as a heat map to show the degree of association between various factors. It assists in identifying traits that are ideal for creating machine learning models. The correlation matrix is converted into colour labelling via the heat map. We may assess which features have high association and which do not using correlation plots. 1 value provides insight into how closely connected the traits are. A score of 0 indicates that a feature has no correlation. we can visualize that area_mean and area_worst has high correlation that is 0.9. also done k-means clustering and no. of clusters are suitable for this dataset is 5 which shown in a WCSS graph.

# %% [markdown]
# #### Q7 - PCA (principal component analysis)

# %%
df_minmax.head(10)
# Out:
#          id  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  0.000915     0.521037      0.022658        0.545989   0.356389
# 1  0.000915     0.643144      0.272574        0.615783   0.495838
# 2  0.092495     0.601496      0.390260        0.595743   0.443062
# 3  0.092547     0.303800      0.360839        0.233501   0.165408
# 4  0.092559     0.629893      0.156578        0.630986   0.483395
# 5  0.000916     0.258839      0.202570        0.267984   0.131597
# 6  0.000917     0.533343      0.347311        0.523875   0.373123
# 7  0.092668     0.318472      0.376057        0.320710   0.174848
# 8  0.000918     0.284869      0.409537        0.302052   0.149918
# 9  0.092715     0.259312      0.484613        0.277659   0.131082
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0         0.593753          0.792037        0.703140             0.731113
# 1         0.289880          0.181768        0.203608             0.348757
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)

# %%
pca.fit(df_minmax)
# Out:
# PCA(n_components=2)

# %%
x_pca=pca.transform(df_minmax)

# %%
df_minmax.shape
# Out:
# (569, 33)

# %%
x_pca.shape
# Out:
# (569, 2)

# %%
x_pca
# Out:
# array([[ 1.39359703,  0.40684434],
#        [ 0.45807995, -0.56289717],
#        [ 0.95683681, -0.12664598],
#        ...,
#        [ 0.22627023, -0.3003479 ],
#        [ 1.6832198 ,  0.31124121],
#        [-0.9022584 , -0.11044023]])

# %%
df.head(10)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
# 5    843786         M        12.45         15.70           82.57      477.1
# 6    844359         M        18.25         19.98          119.60     1040.0
# 7  84458202         M        13.71         20.83           90.20      577.9
# 8    844981         M        13.00         21.82           87.50      519.8
# 9  84501001         M        12.46         24.04           83.97      475.9
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# ...

# %%
df.groupby('diagnosis').mean()
# Out:
#                      id  radius_mean  texture_mean  perimeter_mean  \
# diagnosis
# B          2.654382e+07    12.250300     17.914762       78.075406
# M          3.681805e+07    17.314811     21.604906      115.365377
#
#             area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# diagnosis
# B          471.231373         0.092478          0.080085        0.046058
# M          956.550472         0.102898          0.145188        0.160775
#
#            concave_points_mean  symmetry_mean  ...  perimeter_worst  \
# diagnosis                                      ...
# B                     0.025717       0.174186  ...        87.005938
# M                     0.087990       0.192909  ...       141.370330
#
#             area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# diagnosis
# B           558.899440          0.124959           0.182673         0.166238
# M          1422.286321          0.144845           0.374824         0.450606
#
# ...

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        13.40         20.38           77.58      555.9
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
df.drop("id", axis=1, inplace=True)

# %%
X = df.drop(columns = 'diagnosis', axis=1)
Y = df['diagnosis']

# %%
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        13.40         20.38           77.58      555.9
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave_points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
X.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        13.40         20.38           77.58      555.9          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    compactness_mean  concavity_mean  concave_points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    fractal_dimension_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import StandardScaler

# %%
# train and test split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# standardization
sc_training = StandardScaler()
X_train = sc_training.fit_transform(X_train)
X_test = sc_training.transform(X_test)

# Principal component analysis
pca = PCA()
Z_train = pca.fit_transform(X_train)
Z_test = pca.transform(X_test)

# %%
# Eigenvalues
Eigen_Values = pca.explained_variance_
ell = pca.explained_variance_ratio_

# %%
print(Eigen_Values)
print(ell)
# Out:
# [1.29867458e+01 5.91125295e+00 2.82183874e+00 2.01798247e+00
#  1.74081005e+00 1.25051313e+00 9.93999037e-01 9.31703921e-01
#  6.35444681e-01 4.63065135e-01 4.15774631e-01 3.42992153e-01
#  3.06933867e-01 2.66350430e-01 2.30862318e-01 1.66182773e-01
#  1.00696928e-01 9.34411394e-02 7.52673876e-02 6.16528750e-02
#  4.70228300e-02 4.15372617e-02 3.16601243e-02 2.96346179e-02
#  2.69444327e-02 2.16710917e-02 1.77680801e-02 1.64617804e-02
#  1.30915187e-02 7.21977614e-03 2.78504542e-03 1.17755350e-03]
# [4.04943861e-01 1.84320662e-01 8.79886532e-02 6.29233546e-02
#  5.42807529e-02 3.89926486e-02 3.09942007e-02 2.90517569e-02
#  1.98140031e-02 1.44389815e-02 1.29644013e-02 1.06949476e-02
#  9.57060271e-03 8.30515763e-03 7.19859152e-03 5.18179799e-03
#  3.13986301e-03 2.91361794e-03 2.34693640e-03 1.92241794e-03
#  1.46623385e-03 1.29518659e-03 9.87204427e-04 9.24046464e-04
#  8.40162943e-04 6.75733216e-04 5.54032168e-04 5.13300021e-04
# ...

# %%
# Eigenvalues
Eigen_Values = pca.explained_variance_
ell = pca.explained_variance_ratio_


# Scree plot
plt.subplots(1, 2, figsize = (20, 10))

ax1 = plt.subplot(1, 2, 1)
x = np.arange(len(Eigen_Values)) + 1
ax1.plot(x, Eigen_Values / Eigen_Values.sum(), 'ro-', lw=2)
ax1.set_xticks(x, ["" + str(i) for i in x])
ax1.set_xlabel('Number of components')
ax1.set_ylabel('Explained variance')
ax1.set_title('Scree Plot')
# Out:
# <ipython-input-63-8c1376af78dd>:12: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax1.set_xticks(x, ["" + str(i) for i in x])
# Text(0.5, 1.0, 'Scree Plot')

# %% [markdown]
# ##### A set of correlated variables are transformed into a set of uncorrelated variables using an orthogonal transformation as part of the statistical method known as principal component analysis (PCA). The most often used tool in machine learning for predictive models and exploratory data analysis is PCA. First we covert all the data in a similar range then apply the PCA techniques to reduce the feature size.Before carrying out PCA it is essential to standardize the data. Standardization makes sure that each of the original variables contribute equally to the analysis. PCA is an unsupervised statistical technique that is used to reduce the dimensions of the dataset. ML models with many input variables or higher dimensionality tend to fail when operating on a higher input dataset. PCA helps in identifying relationships among different variables & then coupling them.
# ##### After utilising the first method, using scikit-learn directly to perform Principal Component Analysis seemed so simple. Python does all the aforementioned computations before providing us with a graph (scree plot) that lists the primary components according to the percentage of variance that is explained by each one. The graphic demonstrates that the first three components alone account for around 73 percent of the overall volatility.
